# %% [markdown]
# # DATA EXPLORATION

# %%
# %cd /workspace/src/modeling
# Out:
# /workspace/src/modeling
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import sys
print(sys.path)
# Out:
# ['/usr/lib/python311.zip', '/usr/lib/python3.11', '/usr/lib/python3.11/lib-dynload', '', '/usr/local/lib/python3.11/dist-packages', '/usr/lib/python3/dist-packages']

# %%
from models import Model
# Out:
# 2025-02-03 17:53:58.564763: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import os
import pandas as pd
import numpy as np

# %%
unseen_data = pd.read_csv('/workspace/data/processed/unseen_data.csv')
train_data = '/workspace/data/processed/train_data.csv'
val_data = '/workspace/data/processed/val_data.csv'

# %%
im_weights = os.path.join('/workspace', 'models/image_model_MobileNet.keras')

# %%
classifier = Model(img_model_weights=im_weights)

# %%
classifier.img_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ...

# %%
unseen_data.head()
# Out:
#                                           image_path  \
# 0  /workspace/data/raw/img/image_1100082580_produ...
# 1  /workspace/data/raw/img/image_1139624392_produ...
# 2  /workspace/data/raw/img/image_1271697301_produ...
# 3  /workspace/data/raw/img/image_1313204688_produ...
# 4  /workspace/data/raw/img/image_518749844_produc...
#
#                                          description  \
# 0  <strong>À PROPOS DU JEU</strong>  <b>NKPro Rac...
# 1  <div class="rte"><p>EXIT est un jeu qui repren...
# 2  Bricolage lettres en mousse d&#39;argent Alpha...
# 3  Nostalgique fer blanc Clockwork chaîne Jouet P...
# 4                                                NaN
#
#                         prdtypecode
# 0          downloadable video games
# 1                  children's games
# 2  home accessories and decorations
# 3                   children's toys
# 4                 non-fiction books

# %%
im0 = os.path.join('/workspace', unseen_data['image_path'][4])
print(im0)
# Out:
# /workspace/data/raw/img/image_518749844_product_52594358.jpg

# %%
classifier.predict_img(im0)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1738605248.114786    1163 service.cc:148] XLA service 0x7f56c400cc50 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1738605248.114837    1163 service.cc:156]   StreamExecutor device (0): Host, Default Version
# 2025-02-03 17:54:08.194621: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1738605249.961520    1163 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 'foreign literature'

# %%
classifier.train()
# Out:
# Found 6792 validated image filenames belonging to 27 classes.
# Found 1699 validated image filenames belonging to 27 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 424/424 ━━━━━━━━━━━━━━━━━━━━ 1000s 2s/step - accuracy: 0.3228 - loss: 2.4292 - val_accuracy: 0.1044 - val_loss: 15.9605
